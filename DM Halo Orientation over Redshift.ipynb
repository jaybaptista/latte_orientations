# %%
import numpy as np
import utilities as ut
import gizmo_analysis as gizmo
from ob import getMinAngle, getAngularMomentum, getSymmetryAxes
import pandas as pd

# %%
gals = [
    'm12f_res7100',
#     'm12i_res7100',
    'm12w_res7100',
#     'm12m_res7100'
]

# %%
# %%time
for sim in gals:
    sim_dir = '../../data/latte_metaldiff/' + sim
    step = 30

    radii_data = pd.read_hdf('radii_{}.hdf'.format(sim))
    r_vir = radii_data['virial'][0]
    rs90 = radii_data['star.radius.90'][0]

    radii = [r_vir, rs90, 5*rs90]
    snapshot_range = np.arange(0, 600 + step, step = step)

    part_tmp = gizmo.io.Read.read_snapshots(['dark'], 'snapshot', 600, sim_dir)
    host_min_ax = part_tmp.host['rotation'][0, 2]
    del(part_tmp)

    df = {
        'virial': [],
        'disk': [], # disk is star.radius.90
        '5.disk': []
    }

    for k in np.arange(0,3):

        for snap in snapshot_range:

            part = gizmo.io.Read.read_snapshots(['dark'], 'snapshot', snap, sim_dir)

            positions = part['dark'].prop('host.distance')
            dists = part['dark'].prop('host.distance.total')

            tensor = getSymmetryAxes(positions, dists, radius = radii[k])
            angle = getMinAngle(tensor[2], host_min_ax) * 180/np.pi

            df[list(df.keys())[k]].append(angle)

    d = pd.DataFrame(df)
    d['snapshot'] = snapshot_range
    d.to_hdf('data_obliquityAngles_z_{}_NEW.h5'.format(sim), 'w')
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_600/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 80307825 particles
#     star      (id = 4): 16066489 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (38711.76, 47665.07, 46817.27) [kpc comoving]
#   host1 velocity = (-156.3, 161.7, 106.2) [km / s]
#   host1 axis ratios = (0.16, 0.17, 0.97)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 0, redshift = 99.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_000/snapshot_000.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96239056 particles
#     star      (id = 4): 0 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_000.0.hdf5
#     snapshot_000.1.hdf5
#     snapshot_000.2.hdf5
#     snapshot_000.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (nan, nan, nan) [kpc comoving]
#   host1 velocity = (nan, nan, nan) [km / s]
#   host1 axis ratios = (nan, nan, nan)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 30, redshift = 8.403
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_030/snapshot_030.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96228324 particles
#     star      (id = 4): 10732 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_030.0.hdf5
#     snapshot_030.1.hdf5
#     snapshot_030.2.hdf5
#     snapshot_030.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42483.08, 42682.18, 43828.14) [kpc comoving]
#   host1 velocity = (-29.4, 107.3, 69.8) [km / s]
#   host1 axis ratios = (0.50, 0.74, 0.67)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 60, redshift = 5.429
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_060/snapshot_060.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96164617 particles
#     star      (id = 4): 74479 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_060.0.hdf5
#     snapshot_060.1.hdf5
#     snapshot_060.2.hdf5
#     snapshot_060.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42272.68, 43182.63, 44061.83) [kpc comoving]
#   host1 velocity = (-44.9, 150.9, 58.1) [km / s]
#   host1 axis ratios = (0.41, 0.77, 0.54)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 90, redshift = 3.923
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_090/snapshot_090.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96022470 particles
#     star      (id = 4): 217065 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_090.0.hdf5
#     snapshot_090.1.hdf5
#     snapshot_090.2.hdf5
#     snapshot_090.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42156.31, 43667.07, 44231.91) [kpc comoving]
#   host1 velocity = (-40.3, 184.3, 45.0) [km / s]
#   host1 axis ratios = (0.62, 0.72, 0.87)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 120, redshift = 3.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_120/snapshot_120.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 95750621 particles
#     star      (id = 4): 490145 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_120.0.hdf5
#     snapshot_120.1.hdf5
#     snapshot_120.2.hdf5
#     snapshot_120.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41966.88, 44090.25, 44378.71) [kpc comoving]
#   host1 velocity = (-91.0, 154.4, 48.2) [km / s]
#   host1 axis ratios = (0.26, 0.71, 0.37)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 150, redshift = 2.355
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_150/snapshot_150.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 95094108 particles
#     star      (id = 4): 1152605 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_150.0.hdf5
#     snapshot_150.1.hdf5
#     snapshot_150.2.hdf5
#     snapshot_150.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41724.66, 44495.89, 44553.86) [kpc comoving]
#   host1 velocity = (-128.4, 148.4, 64.5) [km / s]
#   host1 axis ratios = (0.59, 0.68, 0.86)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 180, redshift = 1.890
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_180/snapshot_180.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 93863154 particles
#     star      (id = 4): 2410040 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_180.0.hdf5
#     snapshot_180.1.hdf5
#     snapshot_180.2.hdf5
#     snapshot_180.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41429.81, 44839.81, 44735.56) [kpc comoving]
#   host1 velocity = (-119.8, 115.1, 75.4) [km / s]
#   host1 axis ratios = (0.45, 0.62, 0.73)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 210, redshift = 1.540
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_210/snapshot_210.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 93038224 particles
#     star      (id = 4): 3259214 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_210.0.hdf5
#     snapshot_210.1.hdf5
#     snapshot_210.2.hdf5
#     snapshot_210.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41151.18, 45126.39, 44940.89) [kpc comoving]
#   host1 velocity = (-155.3, 155.7, 115.8) [km / s]
#   host1 axis ratios = (0.65, 0.71, 0.91)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 240, redshift = 1.266
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_240/snapshot_240.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 92203728 particles
#     star      (id = 4): 4114582 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_240.0.hdf5
#     snapshot_240.1.hdf5
#     snapshot_240.2.hdf5
#     snapshot_240.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40874.65, 45430.29, 45167.77) [kpc comoving]
#   host1 velocity = (-152.8, 154.5, 123.0) [km / s]
#   host1 axis ratios = (0.55, 0.60, 0.92)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 270, redshift = 1.045
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_270/snapshot_270.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 90999339 particles
#     star      (id = 4): 5361190 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_270.0.hdf5
#     snapshot_270.1.hdf5
#     snapshot_270.2.hdf5
#     snapshot_270.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40613.53, 45685.06, 45362.61) [kpc comoving]
#   host1 velocity = (-130.2, 132.1, 120.4) [km / s]
#   host1 axis ratios = (0.46, 0.50, 0.92)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 300, redshift = 0.864
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_300/snapshot_300.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 89932746 particles
#     star      (id = 4): 6433639 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_300.0.hdf5
#     snapshot_300.1.hdf5
#     snapshot_300.2.hdf5
#     snapshot_300.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40385.35, 45937.09, 45570.75) [kpc comoving]
#   host1 velocity = (-153.5, 166.9, 147.2) [km / s]
#   host1 axis ratios = (0.51, 0.56, 0.91)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 330, redshift = 0.711
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_330/snapshot_330.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 88868552 particles
#     star      (id = 4): 7500462 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_330.0.hdf5
#     snapshot_330.1.hdf5
#     snapshot_330.2.hdf5
#     snapshot_330.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40153.47, 46213.48, 45766.35) [kpc comoving]
#   host1 velocity = (-147.0, 158.4, 135.7) [km / s]
#   host1 axis ratios = (0.41, 0.43, 0.95)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 360, redshift = 0.582
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_360/snapshot_360.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 87729293 particles
#     star      (id = 4): 8642468 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_360.0.hdf5
#     snapshot_360.1.hdf5
#     snapshot_360.2.hdf5
#     snapshot_360.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39947.18, 46424.58, 45951.00) [kpc comoving]
#   host1 velocity = (-171.7, 175.1, 139.2) [km / s]
#   host1 axis ratios = (0.30, 0.33, 0.92)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 390, redshift = 0.471
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_390/snapshot_390.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 86517199 particles
#     star      (id = 4): 9855314 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_390.0.hdf5
#     snapshot_390.1.hdf5
#     snapshot_390.2.hdf5
#     snapshot_390.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39728.21, 46635.13, 46112.68) [kpc comoving]
#   host1 velocity = (-184.1, 178.0, 127.3) [km / s]
#   host1 axis ratios = (0.22, 0.24, 0.92)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 420, redshift = 0.374
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_420/snapshot_420.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 85380456 particles
#     star      (id = 4): 10992424 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_420.0.hdf5
#     snapshot_420.1.hdf5
#     snapshot_420.2.hdf5
#     snapshot_420.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39520.21, 46831.82, 46253.81) [kpc comoving]
#   host1 velocity = (-190.9, 174.6, 128.7) [km / s]
#   host1 axis ratios = (0.19, 0.20, 0.95)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 450, redshift = 0.290
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_450/snapshot_450.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 84286504 particles
#     star      (id = 4): 12086648 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_450.0.hdf5
#     snapshot_450.1.hdf5
#     snapshot_450.2.hdf5
#     snapshot_450.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39323.09, 47012.99, 46381.57) [kpc comoving]
#   host1 velocity = (-194.5, 179.5, 115.5) [km / s]
#   host1 axis ratios = (0.16, 0.17, 0.94)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 480, redshift = 0.215
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_480/snapshot_480.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 83364012 particles
#     star      (id = 4): 13009388 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_480.0.hdf5
#     snapshot_480.1.hdf5
#     snapshot_480.2.hdf5
#     snapshot_480.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39150.57, 47185.52, 46465.67) [kpc comoving]
#   host1 velocity = (-149.8, 170.9, 98.3) [km / s]
#   host1 axis ratios = (0.15, 0.16, 0.95)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 510, redshift = 0.148
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_510/snapshot_510.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 82573663 particles
#     star      (id = 4): 13799924 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_510.0.hdf5
#     snapshot_510.1.hdf5
#     snapshot_510.2.hdf5
#     snapshot_510.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39023.10, 47330.49, 46570.27) [kpc comoving]
#   host1 velocity = (-143.9, 159.9, 132.4) [km / s]
#   host1 axis ratios = (0.14, 0.15, 0.98)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 540, redshift = 0.088
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_540/snapshot_540.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 81690846 particles
#     star      (id = 4): 14683014 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_540.0.hdf5
#     snapshot_540.1.hdf5
#     snapshot_540.2.hdf5
#     snapshot_540.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (38901.00, 47464.16, 46675.27) [kpc comoving]
#   host1 velocity = (-152.6, 164.7, 119.6) [km / s]
#   host1 axis ratios = (0.15, 0.15, 0.99)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 570, redshift = 0.035
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_570/snapshot_570.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 80813859 particles
#     star      (id = 4): 15560335 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_570.0.hdf5
#     snapshot_570.1.hdf5
#     snapshot_570.2.hdf5
#     snapshot_570.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (38788.41, 47584.61, 46763.59) [kpc comoving]
#   host1 velocity = (-154.9, 164.3, 115.3) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_600/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 80307825 particles
#     star      (id = 4): 16066489 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (38711.76, 47665.07, 46817.27) [kpc comoving]
#   host1 velocity = (-156.3, 161.7, 106.2) [km / s]
#   host1 axis ratios = (0.16, 0.17, 0.97)
#
# Assigning inertia tensor at r =  354.66098 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 0, redshift = 99.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_000/snapshot_000.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96239056 particles
#     star      (id = 4): 0 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_000.0.hdf5
#     snapshot_000.1.hdf5
#     snapshot_000.2.hdf5
#     snapshot_000.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (nan, nan, nan) [kpc comoving]
#   host1 velocity = (nan, nan, nan) [km / s]
#   host1 axis ratios = (nan, nan, nan)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 30, redshift = 8.403
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_030/snapshot_030.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96228324 particles
#     star      (id = 4): 10732 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_030.0.hdf5
#     snapshot_030.1.hdf5
#     snapshot_030.2.hdf5
#     snapshot_030.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42483.08, 42682.18, 43828.14) [kpc comoving]
#   host1 velocity = (-29.4, 107.3, 69.8) [km / s]
#   host1 axis ratios = (0.50, 0.74, 0.67)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 60, redshift = 5.429
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_060/snapshot_060.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96164617 particles
#     star      (id = 4): 74479 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_060.0.hdf5
#     snapshot_060.1.hdf5
#     snapshot_060.2.hdf5
#     snapshot_060.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42272.68, 43182.63, 44061.83) [kpc comoving]
#   host1 velocity = (-44.9, 150.9, 58.1) [km / s]
#   host1 axis ratios = (0.41, 0.77, 0.54)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 90, redshift = 3.923
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_090/snapshot_090.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96022470 particles
#     star      (id = 4): 217065 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_090.0.hdf5
#     snapshot_090.1.hdf5
#     snapshot_090.2.hdf5
#     snapshot_090.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (42156.31, 43667.07, 44231.91) [kpc comoving]
#   host1 velocity = (-40.3, 184.3, 45.0) [km / s]
#   host1 axis ratios = (0.62, 0.72, 0.87)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 120, redshift = 3.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_120/snapshot_120.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 95750621 particles
#     star      (id = 4): 490145 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_120.0.hdf5
#     snapshot_120.1.hdf5
#     snapshot_120.2.hdf5
#     snapshot_120.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41966.88, 44090.25, 44378.71) [kpc comoving]
#   host1 velocity = (-91.0, 154.4, 48.2) [km / s]
#   host1 axis ratios = (0.26, 0.71, 0.37)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 150, redshift = 2.355
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_150/snapshot_150.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 95094108 particles
#     star      (id = 4): 1152605 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_150.0.hdf5
#     snapshot_150.1.hdf5
#     snapshot_150.2.hdf5
#     snapshot_150.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41724.66, 44495.89, 44553.86) [kpc comoving]
#   host1 velocity = (-128.4, 148.4, 64.5) [km / s]
#   host1 axis ratios = (0.59, 0.68, 0.86)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 180, redshift = 1.890
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_180/snapshot_180.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 93863154 particles
#     star      (id = 4): 2410040 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_180.0.hdf5
#     snapshot_180.1.hdf5
#     snapshot_180.2.hdf5
#     snapshot_180.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41429.81, 44839.81, 44735.56) [kpc comoving]
#   host1 velocity = (-119.8, 115.1, 75.4) [km / s]
#   host1 axis ratios = (0.45, 0.62, 0.73)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 210, redshift = 1.540
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_210/snapshot_210.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 93038224 particles
#     star      (id = 4): 3259214 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_210.0.hdf5
#     snapshot_210.1.hdf5
#     snapshot_210.2.hdf5
#     snapshot_210.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (41151.18, 45126.39, 44940.89) [kpc comoving]
#   host1 velocity = (-155.3, 155.7, 115.8) [km / s]
#   host1 axis ratios = (0.65, 0.71, 0.91)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 240, redshift = 1.266
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_240/snapshot_240.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 92203728 particles
#     star      (id = 4): 4114582 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_240.0.hdf5
#     snapshot_240.1.hdf5
#     snapshot_240.2.hdf5
#     snapshot_240.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40874.65, 45430.29, 45167.77) [kpc comoving]
#   host1 velocity = (-152.8, 154.5, 123.0) [km / s]
#   host1 axis ratios = (0.55, 0.60, 0.92)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 270, redshift = 1.045
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_270/snapshot_270.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 90999339 particles
#     star      (id = 4): 5361190 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_270.0.hdf5
#     snapshot_270.1.hdf5
#     snapshot_270.2.hdf5
#     snapshot_270.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40613.53, 45685.06, 45362.61) [kpc comoving]
#   host1 velocity = (-130.2, 132.1, 120.4) [km / s]
#   host1 axis ratios = (0.46, 0.50, 0.92)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 300, redshift = 0.864
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_300/snapshot_300.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 89932746 particles
#     star      (id = 4): 6433639 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_300.0.hdf5
#     snapshot_300.1.hdf5
#     snapshot_300.2.hdf5
#     snapshot_300.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40385.35, 45937.09, 45570.75) [kpc comoving]
#   host1 velocity = (-153.5, 166.9, 147.2) [km / s]
#   host1 axis ratios = (0.51, 0.56, 0.91)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 330, redshift = 0.711
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_330/snapshot_330.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 88868552 particles
#     star      (id = 4): 7500462 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_330.0.hdf5
#     snapshot_330.1.hdf5
#     snapshot_330.2.hdf5
#     snapshot_330.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (40153.47, 46213.48, 45766.35) [kpc comoving]
#   host1 velocity = (-147.0, 158.4, 135.7) [km / s]
#   host1 axis ratios = (0.41, 0.43, 0.95)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 360, redshift = 0.582
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_360/snapshot_360.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 87729293 particles
#     star      (id = 4): 8642468 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_360.0.hdf5
#     snapshot_360.1.hdf5
#     snapshot_360.2.hdf5
#     snapshot_360.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39947.18, 46424.58, 45951.00) [kpc comoving]
#   host1 velocity = (-171.7, 175.1, 139.2) [km / s]
#   host1 axis ratios = (0.30, 0.33, 0.92)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 390, redshift = 0.471
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_390/snapshot_390.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 86517199 particles
#     star      (id = 4): 9855314 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_390.0.hdf5
#     snapshot_390.1.hdf5
#     snapshot_390.2.hdf5
#     snapshot_390.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39728.21, 46635.13, 46112.68) [kpc comoving]
#   host1 velocity = (-184.1, 178.0, 127.3) [km / s]
#   host1 axis ratios = (0.22, 0.24, 0.92)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 420, redshift = 0.374
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_420/snapshot_420.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 85380456 particles
#     star      (id = 4): 10992424 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_420.0.hdf5
#     snapshot_420.1.hdf5
#     snapshot_420.2.hdf5
#     snapshot_420.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39520.21, 46831.82, 46253.81) [kpc comoving]
#   host1 velocity = (-190.9, 174.6, 128.7) [km / s]
#   host1 axis ratios = (0.19, 0.20, 0.95)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 450, redshift = 0.290
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_450/snapshot_450.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 84286504 particles
#     star      (id = 4): 12086648 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_450.0.hdf5
#     snapshot_450.1.hdf5
#     snapshot_450.2.hdf5
#     snapshot_450.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39323.09, 47012.99, 46381.57) [kpc comoving]
#   host1 velocity = (-194.5, 179.5, 115.5) [km / s]
#   host1 axis ratios = (0.16, 0.17, 0.94)
#
# Assigning inertia tensor at r =  14.276332 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12f_res7100/snapshot_times.txt
#
#   using snapshot index = 480, redshift = 0.215
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12f_res7100/output/snapdir_480/snapshot_480.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 83364012 particles
#     star      (id = 4): 13009388 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_480.0.hdf5
#     snapshot_480.1.hdf5
#     snapshot_480.2.hdf5
#     snapshot_480.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12f_res7100/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12f_res7100/track/host_coordinates.hdf5
#   host1 position = (39150.57, 47185.52, 46465.67) [kpc comoving]
#   host1 velocity = (-149.8, 170.9, 98.3) [km / s]
# ...
#     gas       (id = 0): 70602598 particles
#     star      (id = 4): 2692054 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_270.0.hdf5
#     snapshot_270.1.hdf5
#     snapshot_270.2.hdf5
#     snapshot_270.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84705.98, 85866.30, 88930.38) [kpc comoving]
#   host1 velocity = (-40.6, 6.5, 72.5) [km / s]
#   host1 axis ratios = (0.61, 0.63, 0.98)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 300, redshift = 0.864
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_300/snapshot_300.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 70063470 particles
#     star      (id = 4): 3234119 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_300.0.hdf5
#     snapshot_300.1.hdf5
#     snapshot_300.2.hdf5
#     snapshot_300.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84629.18, 85882.81, 89051.55) [kpc comoving]
#   host1 velocity = (-46.6, 10.1, 80.0) [km / s]
#   host1 axis ratios = (0.37, 0.47, 0.78)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 330, redshift = 0.711
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_330/snapshot_330.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 69322916 particles
#     star      (id = 4): 3978350 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_330.0.hdf5
#     snapshot_330.1.hdf5
#     snapshot_330.2.hdf5
#     snapshot_330.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84541.69, 85893.92, 89151.60) [kpc comoving]
#   host1 velocity = (-69.0, 24.6, 56.0) [km / s]
#   host1 axis ratios = (0.29, 0.36, 0.81)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 360, redshift = 0.582
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_360/snapshot_360.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 68209985 particles
#     star      (id = 4): 5099079 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_360.0.hdf5
#     snapshot_360.1.hdf5
#     snapshot_360.2.hdf5
#     snapshot_360.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84476.70, 85941.88, 89224.88) [kpc comoving]
#   host1 velocity = (-31.7, -19.2, 33.0) [km / s]
#   host1 axis ratios = (0.31, 0.37, 0.83)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 390, redshift = 0.471
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_390/snapshot_390.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 67059026 particles
#     star      (id = 4): 6266994 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_390.0.hdf5
#     snapshot_390.1.hdf5
#     snapshot_390.2.hdf5
#     snapshot_390.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84403.49, 85927.05, 89333.96) [kpc comoving]
#   host1 velocity = (-63.9, -11.2, 109.5) [km / s]
#   host1 axis ratios = (0.31, 0.37, 0.85)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 420, redshift = 0.374
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_420/snapshot_420.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 65465736 particles
#     star      (id = 4): 7901545 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_420.0.hdf5
#     snapshot_420.1.hdf5
#     snapshot_420.2.hdf5
#     snapshot_420.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84326.23, 85913.47, 89446.62) [kpc comoving]
#   host1 velocity = (-66.5, -26.8, 97.8) [km / s]
#   host1 axis ratios = (0.45, 0.50, 0.89)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 450, redshift = 0.290
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_450/snapshot_450.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 64601086 particles
#     star      (id = 4): 8785715 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_450.0.hdf5
#     snapshot_450.1.hdf5
#     snapshot_450.2.hdf5
#     snapshot_450.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84264.12, 85898.70, 89545.54) [kpc comoving]
#   host1 velocity = (-54.2, -11.4, 84.6) [km / s]
#   host1 axis ratios = (0.31, 0.34, 0.91)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 480, redshift = 0.215
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_480/snapshot_480.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 63738523 particles
#     star      (id = 4): 9668866 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_480.0.hdf5
#     snapshot_480.1.hdf5
#     snapshot_480.2.hdf5
#     snapshot_480.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84199.52, 85882.08, 89628.70) [kpc comoving]
#   host1 velocity = (-71.7, -7.0, 82.9) [km / s]
#   host1 axis ratios = (0.23, 0.26, 0.88)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 510, redshift = 0.148
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_510/snapshot_510.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 62899768 particles
#     star      (id = 4): 10541452 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_510.0.hdf5
#     snapshot_510.1.hdf5
#     snapshot_510.2.hdf5
#     snapshot_510.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84138.31, 85872.92, 89692.74) [kpc comoving]
#   host1 velocity = (-65.1, -0.3, 74.0) [km / s]
#   host1 axis ratios = (0.20, 0.21, 0.93)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 540, redshift = 0.088
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_540/snapshot_540.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 62052606 particles
#     star      (id = 4): 11464477 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_540.0.hdf5
#     snapshot_540.1.hdf5
#     snapshot_540.2.hdf5
#     snapshot_540.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84083.74, 85870.40, 89761.71) [kpc comoving]
#   host1 velocity = (-64.5, -3.4, 87.4) [km / s]
#   host1 axis ratios = (0.20, 0.22, 0.93)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 570, redshift = 0.035
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_570/snapshot_570.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 61350354 particles
#     star      (id = 4): 12287155 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_570.0.hdf5
#     snapshot_570.1.hdf5
#     snapshot_570.2.hdf5
#     snapshot_570.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (84031.55, 85862.93, 89829.93) [kpc comoving]
#   host1 velocity = (-70.0, -13.1, 94.6) [km / s]
#   host1 axis ratios = (0.23, 0.24, 0.98)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12w_res7100/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12w_res7100/output/snapdir_600/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 73279248 particles
#     dark2     (id = 2): 6998776 particles
#     gas       (id = 0): 60919402 particles
#     star      (id = 4): 12836631 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# ! cannot find MUSIC config file:  data/latte_metaldiff/m12w_res7100/*/*.conf
# ! missing cosmological parameters, assuming the following (from AGORA):
#   assuming omega_baryon = 0.0455
#   assuming sigma_8 = 0.807
#   assuming n_s = 0.961
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12w_res7100/track/host_coordinates.hdf5
#   host1 position = (83998.07, 85856.31, 89877.45) [kpc comoving]
#   host1 velocity = (-63.7, -9.2, 97.2) [km / s]
#   host1 axis ratios = (0.23, 0.25, 0.94)
#
# Assigning inertia tensor at r =  43.15402030944824 kpc
# CPU times: user 1h 19min 8s, sys: 59min 55s, total: 2h 19min 4s
# Wall time: 3h 1min 14s

# %%
df
