# %%
import numpy as np
import utilities as ut
import gizmo_analysis as gizmo
from ob import getMinAngle, getAngularMomentum, getSymmetryAxes
import pandas as pd

# %%
gals = [
#     'm12f_res7100',
    'm12i_res7100',
#     'm12w_res7100',
    'm12m_res7100'
]

# %%
for sim in gals:
    sim_dir = '../data/latte_metaldiff/' + sim
    step = 60

    radii_data = pd.read_hdf('radii_{}.hdf'.format(sim))
    r_vir = radii_data['virial'][0]
    rs90 = radii_data['star.radius.90'][0]

    radii = [r_vir, rs90, 5*rs90]
    snapshot_range = np.arange(0, 600 + step, step = step)

    part_tmp = gizmo.io.Read.read_snapshots(['dark'], 'snapshot', 600, sim_dir)
    host_min_ax = part_tmp.host['rotation'][0, 2]
    del(part_tmp)

    df = {
        'virial': [],
        'disk': [], # disk is star.radius.90
        '5.disk': []
    }

    for k in np.arange(0,3):

        for snap in snapshot_range:

            part = gizmo.io.Read.read_snapshots(['dark'], 'snapshot', snap, sim_dir)

            positions = part['dark'].prop('host.distance')
            dists = part['dark'].prop('host.distance.total')

            tensor = getSymmetryAxes(positions, dists, radius = radii[k])
            angle = getMinAngle(tensor[2], host_min_ax) * 180/np.pi

            df[list(df.keys())[k]].append(angle)

    d = pd.DataFrame(df)
    d['snapshot'] = snapshot_range
    d.to_hdf('data_obliquityAngles_z_{}.h5'.format(sim), 'w')
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_600/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57060074 particles
#     star      (id = 4): 13976485 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.15, 44131.23, 46267.68) [kpc comoving]
#   host1 velocity = (-52.2, 73.6, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.99)
#
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 0, redshift = 99.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_000/snapshot_000.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 96239056 particles
#     dark2     (id = 2): 7591203 particles
#     gas       (id = 0): 96239056 particles
#     star      (id = 4): 0 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_000.0.hdf5
#     snapshot_000.1.hdf5
#     snapshot_000.2.hdf5
#     snapshot_000.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
# ! warning: dark id [min, max] = [7.051e7, 4.199e9]
# ! warning: dark id.child [min, max] = [0.000, 4.295e9]
# ! warning: dark id.generation [min, max] = [0.000, 4.295e9]
# ! warning: dark position [min, max] = [-1.425, 47056.828]
# ! warning: dark mass [min, max] = [-1.425e10, 35181.055]
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (nan, nan, nan) [kpc comoving]
#   host1 velocity = (nan, nan, nan) [km / s]
#   host1 axis ratios = (nan, nan, nan)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 60, redshift = 5.429
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_060/snapshot_060.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 70457898 particles
#     star      (id = 4): 56384 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_060.0.hdf5
#     snapshot_060.1.hdf5
#     snapshot_060.2.hdf5
#     snapshot_060.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (43086.52, 42060.29, 44204.49) [kpc comoving]
#   host1 velocity = (-43.0, 50.9, 9.3) [km / s]
#   host1 axis ratios = (0.29, 0.78, 0.37)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 120, redshift = 3.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_120/snapshot_120.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 70032348 particles
#     star      (id = 4): 483237 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_120.0.hdf5
#     snapshot_120.1.hdf5
#     snapshot_120.2.hdf5
#     snapshot_120.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (43036.46, 42217.52, 44559.58) [kpc comoving]
#   host1 velocity = (-20.9, 75.1, 59.4) [km / s]
#   host1 axis ratios = (0.49, 0.59, 0.83)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 180, redshift = 1.890
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_180/snapshot_180.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 68987441 particles
#     star      (id = 4): 1531295 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_180.0.hdf5
#     snapshot_180.1.hdf5
#     snapshot_180.2.hdf5
#     snapshot_180.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (42830.66, 42529.36, 44873.64) [kpc comoving]
#   host1 velocity = (-58.0, 114.1, 49.9) [km / s]
#   host1 axis ratios = (0.40, 0.71, 0.56)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 240, redshift = 1.266
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_240/snapshot_240.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 67525953 particles
#     star      (id = 4): 3000821 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_240.0.hdf5
#     snapshot_240.1.hdf5
#     snapshot_240.2.hdf5
#     snapshot_240.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (42563.96, 42994.56, 45060.04) [kpc comoving]
#   host1 velocity = (-76.0, 121.3, 55.1) [km / s]
#   host1 axis ratios = (0.43, 0.54, 0.80)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 300, redshift = 0.864
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_300/snapshot_300.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 65127558 particles
#     star      (id = 4): 5448219 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_300.0.hdf5
#     snapshot_300.1.hdf5
#     snapshot_300.2.hdf5
#     snapshot_300.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (42339.95, 43376.87, 45361.00) [kpc comoving]
#   host1 velocity = (-57.9, 90.6, 101.7) [km / s]
#   host1 axis ratios = (0.85, 0.87, 0.98)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 360, redshift = 0.582
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_360/snapshot_360.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 62660063 particles
#     star      (id = 4): 7990047 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_360.0.hdf5
#     snapshot_360.1.hdf5
#     snapshot_360.2.hdf5
#     snapshot_360.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#   read 1 host (position, velocity, principal axes) from:  data/latte_metaldiff/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (42173.29, 43584.92, 45587.83) [kpc comoving]
#   host1 velocity = (-47.3, 99.1, 81.1) [km / s]
#   host1 axis ratios = (0.49, 0.52, 0.95)
#
# Assigning inertia tensor at r =  314.1809 kpc
#
# # in utilities.simulation.Snapshot():
# * reading:  data/latte_metaldiff/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 420, redshift = 0.374
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  data/latte_metaldiff/m12i_res7100/output/snapdir_420/snapshot_420.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 60604061 particles
#     star      (id = 4): 10125042 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['dark']
# * reading particles from:
#     snapshot_420.0.hdf5
#     snapshot_420.1.hdf5
#     snapshot_420.2.hdf5
#     snapshot_420.3.hdf5
#
# * reading cosmological parameters from:  data/latte_metaldiff/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties

# %%
df
