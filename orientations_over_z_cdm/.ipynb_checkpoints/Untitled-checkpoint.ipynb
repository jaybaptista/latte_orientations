# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import orientations as ori
# Out:
# palettable colormaps are not installed
# don't have phil's colormaps

# %%
data = pd.read_hdf("orientations_over_z_variable_radius_m12i_res7100.hdf")

# %%
fig, ax = plt.subplots(dpi=200, figsize=(10,3))
ax.plot(ori.getSnapshotData("../../../data/latte_metaldiff/m12i_res7100/", data["snapshot"].to_numpy())[0], data["virial"], c="b", alpha=1)
ax.plot(ori.getSnapshotData("../../../data/latte_metaldiff/m12i_res7100/", data["snapshot"].to_numpy())[0], data["disk"], c="b", alpha=.25)
ax.plot(ori.getSnapshotData("../../../data/latte_metaldiff/m12i_res7100/", data["snapshot"].to_numpy())[0], data["5.disk"], c="b", alpha=.5)
plt.show()

# %%
# Out:
# <Column name='time[Gyr]' dtype='float64' length=60>
#  0.36655513
#  0.48786459
#   0.6171665
#  0.76988409
#  0.92765101
#  1.09052478
#   1.2609194
#  1.43906732
#  1.62393423
#  1.81321181
#  2.00880353
#  2.21035546
#         ...
# 11.45292774
# 11.69441659
# 11.93394367
# 12.17146945
# 12.40697154
# 12.64042727
#  12.8718187
# 13.10113649
# 13.32836585
# 13.55350759
# 13.77655729
# 13.79874688
